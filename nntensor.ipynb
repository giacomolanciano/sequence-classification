# %%
import tensorflow as tf
import numpy as np

# %%
training_epochs = 25

# %%
learning_rate = 0.01

batch_size = 3

display_step = 1

n_class = 2

X_train = np.array([[223113, 311311], [131129, 112911], [132528, 252811]]).astype('int32')
y_train = np.array([[1,0],[0,1],[0,1]]).astype('int32')
print(X_train)
# Out:
# [[223113 311311]
#  [131129 112911]
#  [132528 252811]]

# %%
x = tf.placeholder("float", shape=X_train.shape)
x
# Out:
# <tf.Tensor 'Placeholder_62:0' shape=(3, 2) dtype=float32>

# %%
y = tf.placeholder("float", shape=y_train.shape)
y
# Out:
# <tf.Tensor 'Placeholder_63:0' shape=(3, 2) dtype=float32>

# %%
W = tf.Variable(tf.zeros([2, 2]))
W

# %%
b = tf.Variable(tf.zeros([2]))
evidence = tf.matmul(x, W) + b
evidence
# Out:
# <tf.Tensor 'add_51:0' shape=(3, 2) dtype=float32>

# %%
activation = tf.nn.softmax(tf.matmul(x, W) + b)
activation
# Out:
# <tf.Tensor 'Softmax_24:0' shape=(3, 2) dtype=float32>

# %%
cross_entropy = y*tf.log(activation)
cross_entropy
# Out:
# <tf.Tensor 'mul_25:0' shape=(3, 2) dtype=float32>

# %%
cost = tf.reduce_mean(-tf.reduce_sum(cross_entropy, reduction_indices=1))
cost
# Out:
# <tf.Tensor 'Mean_25:0' shape=() dtype=float32>

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost)
optimizer

# %%
avg_set = []

epoch_set=[]

# %%
init = tf.global_variables_initializer()

# %%
with tf.Session() as sess:
    sess.run(init)
    for epoch in range(training_epochs):
        avg_cost = 0.
        #total_batch = int(len(X_train)/batch_size)
        total_batch = 10000
        for i in range(total_batch):
            batch_xs = X_train[: batch_size]
            batch_ys = y_train[: batch_size]
            sess.run(optimizer, feed_dict={x: batch_xs, y: batch_ys})
            print(sess.run(cost, feed_dict={x: batch_xs,y: batch_ys}))
            avg_cost += sess.run(cost, feed_dict={x: batch_xs,y: batch_ys})/total_batch
        if epoch % display_step == 0:
            print("Epoch:",'%04d' % (epoch+1),"cost=","{:.9f}".format(avg_cost))

    print(" Training phase finished")
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ...
